# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("bhubaneswar_2018.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2386 entries, 0 to 2385
# Data columns (total 22 columns):
# Unnamed: 0      2386 non-null int64
# date            2386 non-null object
# temp            2386 non-null int64
# dew_pt          2386 non-null int64
# hum             2386 non-null int64
# wind_spd        2385 non-null float64
# wind_gust       0 non-null float64
# dir             1918 non-null object
# vis             2386 non-null int64
# pressure        2365 non-null float64
# wind_chill      0 non-null float64
# heat_index      0 non-null float64
# precip          0 non-null float64
# precip_rate     0 non-null float64
# precip_total    0 non-null float64
# cond            2116 non-null object
# fog             2386 non-null int64
# rain            2386 non-null int64
# snow            2386 non-null int64
# hail            2386 non-null int64
# thunder         2386 non-null int64
# tornado         2386 non-null int64
# dtypes: float64(8), int64(11), object(3)
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                 date  temp  dew_pt  hum  wind_spd  wind_gust  \
# 0           1  2018-01-01 02:30:00    69      64   80       2.3        NaN
# 1           2  2018-01-01 05:30:00    68      65   87       4.6        NaN
# 2           3  2018-01-01 08:30:00    71      64   71       6.9        NaN
# 3           4  2018-01-01 11:30:00    79      69   64       4.6        NaN
# 4           5  2018-01-01 14:30:00    79      64   51       6.9        NaN
#
#     dir  vis  pressure   ...     precip  precip_rate  precip_total  \
# 0   NNW    1     29.87   ...        NaN          NaN           NaN
# 1   NNW    1     29.84   ...        NaN          NaN           NaN
# 2    NW    1     29.92   ...        NaN          NaN           NaN
# 3  East    2     29.89   ...        NaN          NaN           NaN
# 4   ENE    2     29.82   ...        NaN          NaN           NaN
#
#                cond  fog rain  snow  hail  thunder  tornado
# ...

# %%
plt.figure(figsize=[20,15])
sns.heatmap(data.isnull(),yticklabels=False,cmap='viridis')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'temp', 'dew_pt', 'hum', 'wind_spd', 'wind_gust',
#        'dir', 'vis', 'pressure', 'wind_chill', 'heat_index', 'precip',
#        'precip_rate', 'precip_total', 'cond', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'tornado'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0', 'wind_gust', 'wind_chill', 'heat_index', 'precip',
       'precip_rate', 'precip_total','cond', 'fog','snow', 'hail',
       'thunder', 'tornado','dir'],axis=1,inplace= True)

# %%
data.head()
# Out:
#                   date  temp  dew_pt  hum  wind_spd  vis  pressure  rain
# 0  2018-01-01 02:30:00    69      64   80       2.3    1     29.87     0
# 1  2018-01-01 05:30:00    68      65   87       4.6    1     29.84     0
# 2  2018-01-01 08:30:00    71      64   71       6.9    1     29.92     0
# 3  2018-01-01 11:30:00    79      69   64       4.6    2     29.89     0
# 4  2018-01-01 14:30:00    79      64   51       6.9    2     29.82     0

# %%
data=data.set_index('date')

# %%
data.index=pd.DatetimeIndex(data.index)

# %%
data.head()
# Out:
#                      temp  dew_pt  hum  wind_spd  vis  pressure  rain
# date
# 2018-01-01 02:30:00    69      64   80       2.3    1     29.87     0
# 2018-01-01 05:30:00    68      65   87       4.6    1     29.84     0
# 2018-01-01 08:30:00    71      64   71       6.9    1     29.92     0
# 2018-01-01 11:30:00    79      69   64       4.6    2     29.89     0
# 2018-01-01 14:30:00    79      64   51       6.9    2     29.82     0

# %%
data.index.date
# Out:
# array([datetime.date(2018, 1, 1), datetime.date(2018, 1, 1),
#        datetime.date(2018, 1, 1), ..., datetime.date(2018, 11, 1),
#        datetime.date(2018, 11, 1), datetime.date(2018, 11, 1)],
#       dtype=object)

# %%
data.head(26)
# Out:
#                      temp  dew_pt  hum  wind_spd  vis  pressure  rain
# date
# 2018-01-01 02:30:00    69      64   80       2.3    1     29.87     0
# 2018-01-01 05:30:00    68      65   87       4.6    1     29.84     0
# 2018-01-01 08:30:00    71      64   71       6.9    1     29.92     0
# 2018-01-01 11:30:00    79      69   64       4.6    2     29.89     0
# 2018-01-01 14:30:00    79      64   51       6.9    2     29.82     0
# 2018-01-01 17:30:00    76      67   65       6.9    2     29.81     0
# 2018-01-01 20:30:00    74      65   65       4.6    2     29.87     0
# 2018-01-01 23:30:00    71      64   71       4.6    2     29.87     0
# 2018-01-02 02:30:00    69      61   69       4.6    1     29.84     0
# 2018-01-02 05:30:00    62      60   90       4.6    1     29.83     0
# 2018-01-02 08:30:00    66      61   79       5.8    1     29.91     0
# 2018-01-02 11:30:00    79      63   49       3.5    2     29.90     0
# ...

# %%
data_old=data.copy()

# %%
plt.figure(figsize=[20,15])
sns.heatmap(data_old.isnull(),yticklabels=False,cmap='viridis')

# %%
plt.figure(figsize=[20,10])
data_old.pressure.plot()

# %%
plt.figure(figsize=[20,10])
data.pressure.fillna(data.pressure.rolling(104,min_periods=1).mean(),inplace=True)
data.pressure.plot()

# %%
plt.figure(figsize=[20,10])
data_old.wind_spd.plot()

# %%
plt.figure(figsize=[20,10])
data.wind_spd.fillna(data.wind_spd.rolling(26,min_periods=1).mean(),inplace=True)
data.wind_spd.plot()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2386 entries, 2018-01-01 02:30:00 to 2018-11-01 23:30:00
# Data columns (total 7 columns):
# temp        2386 non-null int64
# dew_pt      2386 non-null int64
# hum         2386 non-null int64
# wind_spd    2386 non-null float64
# vis         2386 non-null int64
# pressure    2386 non-null float64
# rain        2386 non-null int64
# dtypes: float64(2), int64(5)
# memory usage: 149.1 KB

# %%
plt.figure(figsize=[20,10])
sns.heatmap(data.isnull(),yticklabels=False,cmap='viridis')

# %%
data.to_csv('cleaned_Data.csv')
